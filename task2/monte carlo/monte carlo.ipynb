# %%
# !python -m pip install -r requirements.txt
# Out:
# Requirement already satisfied: pandas in c:\users\ngk\documents\study\iad_tasks\venv\lib\site-packages (from -r requirements.txt (line 1)) (2.1.3)
# Requirement already satisfied: matplotlib in c:\users\ngk\documents\study\iad_tasks\venv\lib\site-packages (from -r requirements.txt (line 2)) (3.8.2)
# Requirement already satisfied: seaborn in c:\users\ngk\documents\study\iad_tasks\venv\lib\site-packages (from -r requirements.txt (line 3)) (0.13.0)
# Requirement already satisfied: numpy<2,>=1.23.2 in c:\users\ngk\documents\study\iad_tasks\venv\lib\site-packages (from pandas->-r requirements.txt (line 1)) (1.26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ngk\documents\study\iad_tasks\venv\lib\site-packages (from pandas->-r requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ngk\documents\study\iad_tasks\venv\lib\site-packages (from pandas->-r requirements.txt (line 1)) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\ngk\documents\study\iad_tasks\venv\lib\site-packages (from pandas->-r requirements.txt (line 1)) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ngk\documents\study\iad_tasks\venv\lib\site-packages (from matplotlib->-r requirements.txt (line 2)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ngk\documents\study\iad_tasks\venv\lib\site-packages (from matplotlib->-r requirements.txt (line 2)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ngk\documents\study\iad_tasks\venv\lib\site-packages (from matplotlib->-r requirements.txt (line 2)) (4.45.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ngk\documents\study\iad_tasks\venv\lib\site-packages (from matplotlib->-r requirements.txt (line 2)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\ngk\documents\study\iad_tasks\venv\lib\site-packages (from matplotlib->-r requirements.txt (line 2)) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\ngk\documents\study\iad_tasks\venv\lib\site-packages (from matplotlib->-r requirements.txt (line 2)) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ngk\documents\study\iad_tasks\venv\lib\site-packages (from matplotlib->-r requirements.txt (line 2)) (3.1.1)
# Requirement already satisfied: six>=1.5 in c:\users\ngk\documents\study\iad_tasks\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 1)) (1.16.0)

# %%
import random
import matplotlib.pyplot as plt

# %%
num_points = 1000

# %%
points = []
hits = 0
for _ in range(num_points):
    x, y = random.random(), random.random()
    if x*x + y*y < 1.0:
        hits += 1
        points.append((x, y, True))
    else:
        points.append((x, y, "blue"))

# %%
x, y, colors = zip(*points)

fig, ax = plt.subplots() 
fig.set_size_inches(8.0, 8.0)

ax.scatter(x, y, c=colors)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\Documents\Study\IAD_TASKS\venv\Lib\site-packages\matplotlib\axes\_axes.py:4483, in Axes._parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4482 try:  # Is 'c' acceptable as PathCollection facecolors?
# -> 4483     colors = mcolors.to_rgba_array(c)
#    4484 except (TypeError, ValueError) as err:
#
# File ~\Documents\Study\IAD_TASKS\venv\Lib\site-packages\matplotlib\colors.py:503, in to_rgba_array(c, alpha)
#     502     else:
# --> 503         rgba = np.array([to_rgba(cc) for cc in c])
#     504 else:
#
# File ~\Documents\Study\IAD_TASKS\venv\Lib\site-packages\matplotlib\colors.py:503, in <listcomp>(.0)
#     502     else:
# --> 503         rgba = np.array([to_rgba(cc) for cc in c])
#     504 else:
#
# File ~\Documents\Study\IAD_TASKS\venv\Lib\site-packages\matplotlib\colors.py:302, in to_rgba(c, alpha)
#     301 if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 302     rgba = _to_rgba_no_colorcycle(c, alpha)
#     303     try:
#
# File ~\Documents\Study\IAD_TASKS\venv\Lib\site-packages\matplotlib\colors.py:391, in _to_rgba_no_colorcycle(c, alpha)
#     390 if not np.iterable(c):
# --> 391     raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#     392 if len(c) not in [3, 4]:
#
# ValueError: Invalid RGBA argument: True
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 6
#       3 fig, ax = plt.subplots()
#       4 fig.set_size_inches(8.0, 8.0)
# ----> 6 ax.scatter(x, y, c=colors)
#       7 plt.show()
#
# File ~\Documents\Study\IAD_TASKS\venv\Lib\site-packages\matplotlib\__init__.py:1478, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1475 @functools.wraps(func)
#    1476 def inner(ax, *args, data=None, **kwargs):
#    1477     if data is None:
# -> 1478         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1480     bound = new_sig.bind(ax, *args, **kwargs)
#    1481     auto_label = (bound.arguments.get(label_namer)
#    1482                   or bound.kwargs.get(label_namer))
#
# File ~\Documents\Study\IAD_TASKS\venv\Lib\site-packages\matplotlib\axes\_axes.py:4670, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4667 if edgecolors is None:
#    4668     orig_edgecolor = kwargs.get('edgecolor', None)
#    4669 c, colors, edgecolors = \
# -> 4670     self._parse_scatter_color_args(
#    4671         c, edgecolors, kwargs, x.size,
#    4672         get_next_color_func=self._get_patches_for_fill.get_next_color)
#    4674 if plotnonfinite and colors is None:
#    4675     c = np.ma.masked_invalid(c)
#
# File ~\Documents\Study\IAD_TASKS\venv\Lib\site-packages\matplotlib\axes\_axes.py:4492, in Axes._parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4489             raise invalid_shape_exception(c.size, xsize) from err
#    4490         # Both the mapping *and* the RGBA conversion failed: pretty
#    4491         # severe failure => one may appreciate a verbose feedback.
# -> 4492         raise ValueError(
#    4493             f"'c' argument must be a color, a sequence of colors, "
#    4494             f"or a sequence of numbers, not {c!r}") from err
#    4495 else:
#    4496     if len(colors) not in (0, 1, xsize):
#    4497         # NB: remember that a single color is also acceptable.
#    4498         # Besides *colors* will be an empty array if c == 'none'.
#
# ValueError: 'c' argument must be a color, a sequence of colors, or a sequence of numbers, not (True, 'blue', True, True, True, True, True, True, True, True, True, True, True, True, True, 'blue', True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, 'blue', True, True, True, True, True, True, True, True, 'blue', True, True, True, True, True, True, True, True, True, True, True, 'blue', True, True, 'blue', 'blue', True, True, True, True, True, 'blue', True, True, True, 'blue', True, True, 'blue', True, True, True, True, 'blue', True, True, 'blue', True, 'blue', True, True, True, True, True, True, True, True, True, 'blue', True, 'blue', True, True, 'blue', True, True, True, True, True, 'blue', 'blue', True, True, 'blue', True, True, True, True, True, True, True, True, True, True, True, True, 'blue', True, 'blue', True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, 'blue', True, True, 'blue', True, True, 'blue', True, True, True, True, True, True, True, True, 'blue', True, True, True, True, 'blue', True, True, 'blue', True, True, True, True, True, 'blue', 'blue', True, True, 'blue', True, True, True, True, 'blue', 'blue', True, True, True, True, True, True, 'blue', True, True, True, True, True, 'blue', True, True, True, 'blue', True, True, True, 'blue', 'blue', True, True, 'blue', True, True, True, True, True, True, True, 'blue', 'blue', True, True, True, True, True, 'blue', True, True, True, True, True, True, True, 'blue', 'blue', True, True, True, True, True, 'blue', True, 'blue', True, True, 'blue', 'blue', True, True, True, True, True, True, True, True, True, 'blue', True, True, True, True, True, 'blue', True, True, True, True, True, True, True, True, True, 'blue', True, True, True, True, True, True, 'blue', True, True, True, True, True, 'blue', True, True, True, 'blue', True, 'blue', True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, 'blue', True, 'blue', 'blue', True, 'blue', True, True, True, True, 'blue', True, 'blue', 'blue', True, True, 'blue', True, True, 'blue', True, True, 'blue', True, True, 'blue', 'blue', 'blue', True, True, True, True, 'blue', 'blue', True, True, True, True, True, True, True, True, 'blue', True, 'blue', True, 'blue', 'blue', True, True, True, True, 'blue', True, True, True, True, True, True, True, True, True, True, True, True, 'blue', True, True, True, True, True, True, True, True, True, 'blue', True, 'blue', True, 'blue', True, 'blue', True, True, True, True, 'blue', True, True, True, True, True, True, True, True, True, 'blue', 'blue', 'blue', 'blue', 'blue', True, True, 'blue', True, True, True, 'blue', True, True, True, True, 'blue', True, True, True, True, 'blue', True, True, True, True, True, True, True, True, True, 'blue', True, True, True, True, True, True, 'blue', 'blue', 'blue', True, True, 'blue', True, True, True, True, True, True, True, True, True, True, True, 'blue', True, True, 'blue', True, True, 'blue', True, True, True, True, True, True, 'blue', True, True, True, True, True, 'blue', 'blue', True, 'blue', True, True, True, True, True, True, 'blue', True, True, True, 'blue', True, 'blue', True, 'blue', True, True, True, True, 'blue', True, True, True, True, True, True, True, True, 'blue', True, True, True, True, 'blue', True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, 'blue', True, True, True, 'blue', 'blue', True, True, True, 'blue', True, True, True, True, True, 'blue', True, True, True, 'blue', 'blue', True, True, 'blue', True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, 'blue', 'blue', 'blue', True, True, True, True, 'blue', True, 'blue', True, True, True, 'blue', True, True, True, True, True, True, True, True, True, True, True, True, True, True, 'blue', 'blue', 'blue', True, True, True, True, True, True, True, True, 'blue', 'blue', 'blue', T ...

# %%
fraction = hits / num_points
4 * fraction
# Out:
# 3.14
